# %%
import os
import sys

# necessary for calling stuff since we are in notebook folder
# Add parent directory to path
parent_dir = os.path.dirname(os.getcwd())
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)
os.chdir(parent_dir)

from dotenv import load_dotenv
from openai import OpenAI
import json
from services import UseCaseService

# %%
# load API key
load_dotenv()
api_key = os.getenv("OPENROUTER_API_KEY")

# %%
# init client
client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=api_key
)

service = UseCaseService()

# %% [markdown]
# # Implement Tools jsons (UPDATED, a better version is below)

# %%
if 1 == 2:
    # get all use cases
    tool_get_all_use_cases = {
        "type" : "function", 
        "function" : {
            "name" : "get_all_use_cases", 
            "description" : "Get all use cases from the database. Use this when the user wants to see all use cases, list use cases, or get an overview.", 
            "parameters" : {
                "type" : "object", 
                "properties" : {},  # has not parameters
                "required" : []  # obviously no parameters required
            }
        }
    }

    # get use case by ID
    tool_get_use_case_by_id = {
        "type" : "function", 
        "function" : {
            "name" : "get_use_case_by_id",
            "description" : "Get detailed information about a specific use case by its ID. Use this when the user asks about a specific use case number.",
            "parameters" : {
                "type" : "object", 
                "properties" : {
                    "use_case_id" : {
                        "type" : "integer", 
                        "description" : "The ID of the use case to retrieve (e.g., 1, 2, 3)"
                    }
                },
                "required": ["use_case_id"]
            }
        }
    }

    # create use case
    tool_create_use_case = {
        "type" : "function",
        "function" : {
            "name" : "create_use_case",
            "description" : "Create a new use case in the database. Use this when the user wants to add a new use case or create a use case from workshop transcripts.",
            "parameters" : {
                "type" : "object",
                "properties" : {
                    "title" : {
                        "type" : "string", 
                        "description": "The title of the use case (required, non-empty)"
                    },
                    "description": {
                        "type": "string",
                        "description": "Detailed description of the use case (optional)"
                    },
                    "expected_benefit": {
                        "type": "string",
                        "description": "Expected benefits or value of the use case (optional)"
                    },
                    "company_id": {
                        "type": "integer",
                        "description": "ID of the company this use case belongs to (required)"
                    },
                    "industry_id": {
                        "type": "integer",
                        "description": "ID of the industry this use case belongs to (required)"
                    },
                    "status": {
                        "type": "string",
                        "description": "Initial status (optional, defaults to 'new'). Valid values: new, in_review, approved, in_progress, completed, archived"
                    }
                },
                "required": ["title", "company_id", "industry_id"]
            }
        }
    }

    # update use case
    tool_update_use_case = {
        "type": "function",
        "function": {
            "name": "update_use_case",
            "description": "Update an existing use case. Only provided fields will be updated. Use this when the user wants to modify or change a use case.",
            "parameters": {
                "type": "object",
                "properties": {
                    "use_case_id": {
                        "type": "integer",
                        "description": "ID of the use case to update (required)"
                    },
                    "title": {
                        "type": "string",
                        "description": "New title (optional)"
                    },
                    "description": {
                        "type": "string",
                        "description": "New description (optional)"
                    },
                    "expected_benefit": {
                        "type": "string",
                        "description": "New expected benefit (optional)"
                    },
                    "status": {
                        "type": "string",
                        "description": "New status (optional). Valid: new, in_review, approved, in_progress, completed, archived"
                    },
                    "company_id": {
                        "type": "integer",
                        "description": "New company ID (optional)"
                    },
                    "industry_id": {
                        "type": "integer",
                        "description": "New industry ID (optional)"
                    }
                },
                "required": ["use_case_id"]
            }
        }
    }

    # update status
    tool_update_use_case_status = {
        "type": "function",
        "function": {
            "name": "update_use_case_status",
            "description": "Update the status of a use case. Use this when the user wants to change only the status (e.g., 'approve use case 5', 'mark use case 3 as completed').",
            "parameters": {
                "type": "object",
                "properties": {
                    "use_case_id": {
                        "type": "integer",
                        "description": "ID of the use case"
                    },
                    "status": {
                        "type": "string",
                        "description": "New status value. Valid: new, in_review, approved, in_progress, completed, archived"
                    }
                },
                "required": ["use_case_id", "status"]
            }
        }
    }

    # delet use case
    tool_delete_use_case = {
        "type": "function",
        "function": {
            "name": "delete_use_case",
            "description": "Delete a use case from the database. Use this when the user wants to remove or delete a use case.",
            "parameters": {
                "type": "object",
                "properties": {
                    "use_case_id": {
                        "type": "integer",
                        "description": "ID of the use case to delete"
                    }
                },
                "required": ["use_case_id"]
            }
        }
    }

    # filter use cases
    tool_filter_use_cases = {
        "type": "function",
        "function": {
            "name": "filter_use_cases",
            "description": "Filter use cases by industry, company, status, or person. Use this when the user asks for use cases matching specific criteria (e.g., 'show me all use cases in the energy sector', 'what use cases are in progress').",
            "parameters": {
                "type": "object",
                "properties": {
                    "industry_id": {
                        "type": "integer",
                        "description": "Filter by industry ID (optional)"
                    },
                    "company_id": {
                        "type": "integer",
                        "description": "Filter by company ID (optional)"
                    },
                    "status": {
                        "type": "string",
                        "description": "Filter by status (optional). Valid: new, in_review, approved, in_progress, completed, archived"
                    },
                    "person_id": {
                        "type": "integer",
                        "description": "Filter by person who contributed (optional)"
                    }
                },
                "required": [] 
            }
        }
    }

# %%
if 1 == 2:  # better version is below
    # Combine all tools into a list
    tools = [
        tool_get_all_use_cases,
        tool_get_use_case_by_id,
        tool_create_use_case,
        tool_update_use_case,
        tool_update_use_case_status,
        tool_delete_use_case,
        tool_filter_use_cases
    ]

    print(f"Defined {len(tools)} tools for the agent")
    for tool in tools:
        print(f"  - {tool['function']['name']}")

# %% [markdown]
# # UPDATED TOOL WITH MORE PRECISE DESCRIPTIONS

# %%
# Tool 1: Get all use cases
tool_get_all_use_cases = {
    "type": "function",
    "function": {
        "name": "get_all_use_cases",
        "description": (
            "Retrieve all use cases from the database. "
            "Use this when the user wants to see all use cases, list use cases, "
            "or get an overview of everything in the system. "
            "Returns comprehensive information including title, description, status, "
            "company, and industry for each use case."
        ),
        "parameters": {
            "type": "object",
            "properties": {},
            "required": []
        }
    }
}

# Tool 2: Get use case by ID
tool_get_use_case_by_id = {
    "type": "function",
    "function": {
        "name": "get_use_case_by_id",
        "description": (
            "Get detailed information about a specific use case by its ID number. "
            "Use this when the user mentions a specific use case number or ID "
            "(e.g., 'use case 5', 'UC #3', 'number 7'). "
            "Returns all details including title, description, status, company, industry, and benefits."
        ),
        "parameters": {
            "type": "object",
            "properties": {
                "use_case_id": {
                    "type": "integer",
                    "description": "The numeric ID of the use case to retrieve (e.g., 1, 2, 3, etc.)"
                }
            },
            "required": ["use_case_id"]
        }
    }
}

# Tool 3: Create use case
tool_create_use_case = {
    "type": "function",
    "function": {
        "name": "create_use_case",
        "description": (
            "Create a new use case in the database. "
            "Use this when the user wants to add a new use case, extract use cases from transcripts, "
            "or create entries based on workshop discussions. "
            "IMPORTANT: You must provide company_id and industry_id as integers. "
            "If the user mentions company/industry names, you may need to ask for clarification "
            "or reference existing data to find the correct IDs."
        ),
        "parameters": {
            "type": "object",
            "properties": {
                "title": {
                    "type": "string",
                    "description": "The title/name of the use case (required, must not be empty). Be concise but descriptive."
                },
                "description": {
                    "type": "string",
                    "description": (
                        "Detailed description of what the use case involves, the problem it solves, "
                        "and how it works (optional but recommended)"
                    )
                },
                "expected_benefit": {
                    "type": "string",
                    "description": (
                        "Expected benefits, value, or outcomes of implementing this use case "
                        "(optional). Include quantitative metrics if available."
                    )
                },
                "company_id": {
                    "type": "integer",
                    "description": (
                        "ID of the company this use case belongs to (required). "
                        "This must be a valid company ID number from the database."
                    )
                },
                "industry_id": {
                    "type": "integer",
                    "description": (
                        "ID of the industry this use case belongs to (required). "
                        "This must be a valid industry ID number from the database."
                    )
                },
                "status": {
                    "type": "string",
                    "description": (
                        "Initial status for the use case (optional, defaults to 'new'). "
                        "Must be EXACTLY one of the valid status values listed in enum. "
                        "Map user's language/intent to these exact values: "
                        "'neu'/'new'→'new', 'in Prüfung'/'in review'→'in_review', "
                        "'genehmigt'/'approved'→'approved', 'in Arbeit'/'in progress'→'in_progress', "
                        "'fertig'/'done'/'completed'→'completed', 'archiviert'/'archived'→'archived'"
                    ),
                    "enum": ["new", "in_review", "approved", "in_progress", "completed", "archived"]
                }
            },
            "required": ["title", "company_id", "industry_id"]
        }
    }
}

# Tool 4: Update use case
tool_update_use_case = {
    "type": "function",
    "function": {
        "name": "update_use_case",
        "description": (
            "Update an existing use case. Only the fields you provide will be changed; "
            "all other fields remain unchanged. "
            "Use this when the user wants to modify, change, or edit a use case. "
            "You can update any combination of title, description, benefit, status, company, or industry."
        ),
        "parameters": {
            "type": "object",
            "properties": {
                "use_case_id": {
                    "type": "integer",
                    "description": "ID of the use case to update (required)"
                },
                "title": {
                    "type": "string",
                    "description": "New title (optional). If provided, must not be empty."
                },
                "description": {
                    "type": "string",
                    "description": "New description (optional)"
                },
                "expected_benefit": {
                    "type": "string",
                    "description": "New expected benefit (optional)"
                },
                "status": {
                    "type": "string",
                    "description": (
                        "New status (optional). Must be EXACTLY one of the valid values in enum. "
                        "Translate user's intent: 'neu'→'new', 'In Bewertung'/'zur Prüfung'→'in_review', "
                        "'genehmigt'/'freigegeben'→'approved', 'in Bearbeitung'/'in Arbeit'→'in_progress', "
                        "'abgeschlossen'/'fertig'→'completed', 'archiviert'→'archived'"
                    ),
                    "enum": ["new", "in_review", "approved", "in_progress", "completed", "archived"]
                },
                "company_id": {
                    "type": "integer",
                    "description": "New company ID (optional). Must be a valid company ID from the database."
                },
                "industry_id": {
                    "type": "integer",
                    "description": "New industry ID (optional). Must be a valid industry ID from the database."
                }
            },
            "required": ["use_case_id"]
        }
    }
}

# Tool 5: Update status (specialized)
tool_update_use_case_status = {
    "type": "function",
    "function": {
        "name": "update_use_case_status",
        "description": (
            "Update ONLY the status of a use case. This is a convenience function for status-only changes. "
            "Use this when the user wants to change, set, or update just the status "
            "(e.g., 'approve use case 5', 'mark case 3 as completed', 'set UC 7 to in progress'). "
            "CRITICAL: Always map the user's language/intent to one of the exact valid status values."
        ),
        "parameters": {
            "type": "object",
            "properties": {
                "use_case_id": {
                    "type": "integer",
                    "description": "ID of the use case whose status should be changed"
                },
                "status": {
                    "type": "string",
                    "description": (
                        "New status value. Must be EXACTLY one of the values in enum. "
                        "Language mapping examples: "
                        "German: 'neu'→'new', 'In Bewertung'/'In Prüfung'→'in_review', 'genehmigt'→'approved', "
                        "'in Bearbeitung'/'läuft'→'in_progress', 'abgeschlossen'/'fertig'/'erledigt'→'completed', "
                        "'archiviert'→'archived'. "
                        "English variants: 'reviewing'→'in_review', 'working on'/'ongoing'→'in_progress', "
                        "'done'/'finished'→'completed'"
                    ),
                    "enum": ["new", "in_review", "approved", "in_progress", "completed", "archived"]
                }
            },
            "required": ["use_case_id", "status"]
        }
    }
}

# Tool 6: Delete use case
tool_delete_use_case = {
    "type": "function",
    "function": {
        "name": "delete_use_case",
        "description": (
            "Permanently delete a use case from the database. "
            "Use this when the user explicitly wants to remove, delete, or eliminate a use case. "
            "WARNING: This action cannot be undone. The function returns information about "
            "the deleted use case for confirmation. "
            "Consider suggesting archiving instead of deletion when appropriate."
        ),
        "parameters": {
            "type": "object",
            "properties": {
                "use_case_id": {
                    "type": "integer",
                    "description": "ID of the use case to delete permanently"
                }
            },
            "required": ["use_case_id"]
        }
    }
}

# Tool 7: Filter use cases
tool_filter_use_cases = {
    "type": "function",
    "function": {
        "name": "filter_use_cases",
        "description": (
            "Filter and search use cases by various criteria. All filters are optional - "
            "you can use one or combine multiple filters. "
            "Use this when the user wants use cases matching specific conditions "
            "(e.g., 'show energy sector use cases', 'what's in progress', 'cases from company X'). "
            "Returns a list of use cases matching ALL provided filters (AND logic)."
        ),
        "parameters": {
            "type": "object",
            "properties": {
                "industry_id": {
                    "type": "integer",
                    "description": (
                        "Filter by industry ID (optional). "
                        "Only return use cases belonging to this specific industry. "
                        "Must be a valid industry ID number from the database."
                    )
                },
                "company_id": {
                    "type": "integer",
                    "description": (
                        "Filter by company ID (optional). "
                        "Only return use cases belonging to this specific company. "
                        "Must be a valid company ID number from the database."
                    )
                },
                "status": {
                    "type": "string",
                    "description": (
                        "Filter by status (optional). Only return use cases with this exact status. "
                        "Must be EXACTLY one of the valid values in enum. "
                        "Map user's language: 'neu'/'new'→'new', 'in Bewertung'/'zur Prüfung'→'in_review', "
                        "'genehmigt'/'approved'→'approved', 'laufend'/'in Arbeit'/'in progress'→'in_progress', "
                        "'fertig'/'abgeschlossen'/'done'→'completed', 'archiviert'/'archived'→'archived'"
                    ),
                    "enum": ["new", "in_review", "approved", "in_progress", "completed", "archived"]
                },
                "person_id": {
                    "type": "integer",
                    "description": (
                        "Filter by person who contributed (optional). "
                        "Only return use cases that this specific person contributed to. "
                        "Must be a valid person ID number from the database."
                    )
                }
            },
            "required": []
        }
    }
}

# Combine all tools into a list
tools = [
    tool_get_all_use_cases,
    tool_get_use_case_by_id,
    tool_create_use_case,
    tool_update_use_case,
    tool_update_use_case_status,
    tool_delete_use_case,
    tool_filter_use_cases
]

# %% [markdown]
# # Tool -> function mapping

# %%
tool_functions = {
    "get_all_use_cases": service.get_all_use_cases,
    "get_use_case_by_id": service.get_use_case_by_id,
    "create_use_case": service.create_use_case,
    "update_use_case": service.update_use_case,
    "update_use_case_status": service.update_use_case_status,
    "delete_use_case": service.delete_use_case,
    "filter_use_cases": service.filter_use_cases
}

# %% [markdown]
# # implement a function that takes the function name and calls the real function and returns result

# %%
def execute_tool(function_name : str, arguments : dict):

    # check if function exists
    if function_name not in tool_functions.keys():
        return {"error" : f"Unknown function: {function_name}"}

    try: 
        actual_function = tool_functions[function_name]

        # call the function
        result = actual_function(**arguments)

        return result
    
    except Exception as e:
        return {"error" : str(e)}

# %%
def run_agent(user_message : str, verbose: bool = True):
    print(f"\nUser: {user_message}\n")

    # (1) Call agent with user message
    agent_response_1 = client.chat.completions.create(
        model="anthropic/claude-3.5-sonnet",
        messages=[
            {"role" : "user", "content" : user_message}
        ],
        tools=tools, 
        max_tokens=2000
    )
    agent_message_1 = agent_response_1.choices[0].message

    # (2) the agent might want to call a tool or more
    if agent_message_1.tool_calls:
        if verbose:
            print(f"\nThe agent wants to call {len(agent_message_1.tool_calls)} tools.")


        # safe dialog
        all_messages = [
            {"role" : "user", "content" : user_message},  # user input
            agent_message_1  # agent's first response containing the tool call
        ]

        # execute the agent's tool call or all tool calls
        for tool_call in agent_message_1.tool_calls: 

            # get function name and it's arguments
            function_name = tool_call.function.name
            arguments_str = tool_call.function.arguments
            
            # format arguments if nestled in str
            if arguments_str and arguments_str.strip():
                arguments = json.loads(arguments_str)
            else:
                arguments = {}  # Empty dict for functions with no parameters

            if verbose:
                print(f"\nAgent calls {function_name}")
                if arguments:
                    print(f"Arguments: {arguments}")
                else:
                    print(f"Arguments: (none)")
            
            # runs the tool function
            result = execute_tool(function_name, arguments)

            if verbose:
                if isinstance(result, list):
                    print(f"Returned {len(result)} items")
                elif isinstance(result, dict):
                    if "error" in result:
                        print(f"Error: {result['error']}")
                    else:
                        print(f"Success: {result.get('title', 'OK')}")
                else:
                    print(f"Result: {result}")

            # add the result to the whole dialog
            all_messages.append({
                "role": "tool",
                "tool_call_id": tool_call.id,
                "content": json.dumps(result)
            })

        # (3) send to result and all messages back to the LLM for final answer, this time without any tools
        if verbose:
            print(f"\nSending results back to LLM for final answer...")
        agent_response_2 = client.chat.completions.create(
            model="anthropic/claude-3.5-sonnet",
            messages=all_messages,
            max_tokens=2000
        )
        final_answer = agent_response_2.choices[0].message.content
        print(f"Agent: {final_answer}")

        return final_answer
    
    else:  # agent does not want to call any tools
        if verbose:
            print(f"\nAgent responding directly (no tools needed)")
        print(f"Agent: {agent_message_1.content}")

        return agent_message_1.content

# %% [markdown]
# # Test some calls

# %%
run_agent("Show me all use cases")

# %%
run_agent("Tell me about use case number 1")

# %%
run_agent("Please change the status of use case 12 to in_review")

# %%
run_agent("please show me all use cases with status in_review. Please also share their IDs.")

# %% [markdown]
# # Test tool calls

# %%
print("\n" + "="*80)
print("TEST 1: GET ALL USE CASES")
print("="*80)
run_agent("Show me all use cases")

# Test 2: Get specific use case
print("\n" + "="*80)
print("TEST 2: GET USE CASE BY ID")
print("="*80)
run_agent("Tell me about use case number 1")

# Test 3: Filter by status
print("\n" + "="*80)
print("TEST 3: FILTER BY STATUS")
print("="*80)
run_agent("Show me all use cases with status 'new'")


# Test 4: Update status
print("\n" + "="*80)
print("TEST 4: UPDATE STATUS")
print("="*80)
run_agent("Change use case 1 to status 'in_progress'")

# Test 5: Create use case
print("\n" + "="*80)
print("TEST 5: CREATE USE CASE")
print("="*80)
run_agent("Create a new use case called 'Test Agent Integration' for company 1 in industry 2")
# Out:
# ================================================================================
# TEST 1: GET ALL USE CASES
# ================================================================================
#
# User: Show me all use cases
#
#
# The agent wants to call 1 tools.
#
# Agent calls get_all_use_cases
# Arguments: (none)
# Returned 21 items
#
# Sending results back to LLM for final answer...
# Agent: Here's a summary of all use cases in the database:
#
# Healthcare Industry:
# 1. Patient Portal (MediCare Solutions Inc.) - Status: in_progress
# 2. AI Diagnostics (HealthFirst Medical Group) - Status: in_progress
# 3. EHR Migration (CarePlus Health Services) - Status: completed
#
# IT Industry:
# 4. Cloud Migration (DataStream Systems) - Status: new
# 5. Mobile App Dev (TechVision Innovations) - Status: in_progress
# 6. Cybersecurity Program (ByteForge Solutions) - Status: new
# 7. Multiple Automated Testing implementations (ByteForge Solutions) - Status: various
# 8. Test Agent Integration cases (MediCare Solutions Inc.) - Status: new
#
# Manufacturing Industry:
# 9. IoT Sensors (Precision Parts Industries) - Status: in_progress
# 10. Supply Chain Optimization (Global Fabrication Systems) - Status: new
# 11. Quality Control Automation (Pioneer Industrial Products) - Status: completed
#
# The use cases span across three main industries (Healthcare, IT, and Manufacturing) with various statuses including new, in_progress, and completed. There are several test cases and implementations related to automated testing, primarily associated with ByteForge Solutions.
#
# Would you like more detailed information about any specific use case or industry?
#
# ================================================================================
# TEST 2: GET USE CASE BY ID
# ================================================================================
#
# User: Tell me about use case number 1
#
#
# The agent wants to call 1 tools.
#
# Agent calls get_use_case_by_id
# Arguments: {'use_case_id': 1}
# Success: Patient protal
#
# Sending results back to LLM for final answer...
# Agent: Based on the retrieved information, here are the details for use case #1:
#
# Title: Patient Portal
# Company: MediCare Solutions Inc.
# Industry: Healthcare
# Status: In Progress
# Description: Portal online for patients
# Expected Benefit: Better patient administration
#
# This use case involves implementing an online patient portal in the healthcare industry. It's being developed by MediCare Solutions Inc. with the goal of improving patient administration. The project is currently in progress.
#
# A patient portal typically allows patients to:
# - Access their medical records
# - Schedule appointments
# - Communicate with healthcare providers
# - View test results
# - Request prescription refills
#
# This digital solution aims to streamline patient administration processes and improve the overall healthcare service delivery.
#
# ================================================================================
# TEST 3: FILTER BY STATUS
# ================================================================================
#
# User: Show me all use cases with status 'new'
#
#
# The agent wants to call 1 tools.
#
# Agent calls filter_use_cases
# Arguments: {'status': 'new'}
# Returned 14 items
#
# Sending results back to LLM for final answer...
# Agent: Here are all the use cases with status 'new':
#
# 1. Cloud Migration (DataStream Systems)
# 2. Cybersecurity Program (ByteForge Solutions)
# 3. Supply Chain Optimization (Global Fabrication Systems)
# 4. Test Use Case - Automated Testing (ByteForge Solutions) [Multiple entries]
# 5. Test Agent Integration (MediCare Solutions Inc.) [Multiple entries]
#
# There are 14 use cases in total with 'new' status. Many of these appear to be test entries with the same title "Test Use Case - Automated Testing" for ByteForge Solutions and "Test Agent Integration" for MediCare Solutions Inc.
#
# Would you like to see more details about any specific use case from this list?
#
# ================================================================================
# TEST 4: UPDATE STATUS
# ================================================================================
#
# User: Change use case 1 to status 'in_progress'
#
#
# The agent wants to call 1 tools.
#
# Agent calls update_use_case_status
# Arguments: {'use_case_id': 1, 'status': 'in_progress'}
# Success: Patient protal
#
# Sending results back to LLM for final answer...
# Agent: The use case status has been successfully updated to 'in_progress'. You can see the updated details in the response above.
#
# ================================================================================
# TEST 5: CREATE USE CASE
# ================================================================================
#
# User: Create a new use case called 'Test Agent Integration' for company 1 in industry 2
#
#
# The agent wants to call 1 tools.
#
# Agent calls create_use_case
# Arguments: {'title': 'Test Agent Integration', 'company_id': 1, 'industry_id': 2}
# Success: Test Agent Integration
#
# Sending results back to LLM for final answer...
# Agent: Great! I've created a new use case with the following details:
# - ID: 22
# - Title: Test Agent Integration
# - Company: MediCare Solutions Inc.
# - Industry: IT
# - Status: new
#
# The use case has been successfully created. Would you like to add any additional details like a description or expected benefits to this use case?
# "Great! I've created a new use case with the following details:\n- ID: 22\n- Title: Test Agent Integration\n- Company: MediCare Solutions Inc.\n- Industry: IT\n- Status: new\n\nThe use case has been successfully created. Would you like to add any additional details like a description or expected benefits to this use case?"

# %%
print("\n" + "="*80)
print("FURTHER AGENT TESTING")
print("="*80)

# Test 1: German status update
print("\n--- TEST 1: German Status Update ---")
run_agent("Bitte setze Use Case 1 auf Status 'In Bewertung'", verbose=True)

# Test 2: Typo tolerance
print("\n--- TEST 2: Typo in Status ---")
run_agent("Show me use cases that are 'in progres'", verbose=True)

# Test 3: Mixed language
print("\n--- TEST 3: Mixed German/English ---")
run_agent("Filter nach Status abgeschlossen", verbose=True)

# Test 4: Natural language status
print("\n--- TEST 4: Natural Language Status ---")
run_agent("Mark use case 2 as done", verbose=True)

# Test 5: Multiple variations
print("\n--- TEST 5: Status Variation ---")
run_agent("Set use case 3 to 'reviewing'", verbose=True)

# Test 6: Complex query
print("\n--- TEST 6: Filter Combination ---")
run_agent("Show me all use cases in industry 1 that are approved", verbose=True)

# Test 7: Create with German status
print("\n--- TEST 7: Create with German ---")
run_agent("Erstelle einen neuen Use Case 'Test Deutsch' für Firma 1 in Branche 1 mit Status 'genehmigt'", verbose=True)
# Out:
# ================================================================================
# FURTHER AGENT TESTING
# ================================================================================
#
# --- TEST 1: German Status Update ---
#
# User: Bitte setze Use Case 1 auf Status 'In Bewertung'
#
#
# The agent wants to call 1 tools.
#
# Agent calls update_use_case_status
# Arguments: {'use_case_id': 1, 'status': 'in_review'}
# Success: Patient protal
#
# Sending results back to LLM for final answer...
# Agent: Der Status von Use Case 1 wurde erfolgreich auf "In Bewertung" geändert.
#
# --- TEST 2: Typo in Status ---
#
# User: Show me use cases that are 'in progres'
#
#
# The agent wants to call 1 tools.
#
# Agent calls filter_use_cases
# Arguments: {'status': 'in_progress'}
# Returned 3 items
#
# Sending results back to LLM for final answer...
# Agent: Here are the use cases that are currently in progress:
#
# 1. AI Diagnostics (HealthFirst Medical Group - Healthcare)
#    - Description: ML for medical imaging
#    - Expected Benefit: Faster diagnosis
#
# 2. Mobile App Dev (TechVision Innovations - IT)
#    - Description: iOS and Android apps
#    - Expected Benefit: Increased engagement
#
# 3. IoT Sensors (Precision Parts Industries - Manufacturing)
#    - Description: Real-time equipment monitoring
#    - Expected Benefit: Reduced downtime
#
# There are 3 use cases currently marked as "in progress" across different industries: Healthcare, IT, and Manufacturing. Each appears to be focusing on different technological implementations to achieve specific business benefits.
#
# Would you like more detailed information about any of these specific use cases?
#
# --- TEST 3: Mixed German/English ---
#
# User: Filter nach Status abgeschlossen
#
#
# The agent wants to call 1 tools.
#
# Agent calls filter_use_cases
# Arguments: {'status': 'completed'}
# Returned 2 items
#
# Sending results back to LLM for final answer...
# Agent: Hier sind die abgeschlossenen Use Cases:
#
# 1. EHR Migration
# - Unternehmen: CarePlus Health Services (Healthcare)
# - Beschreibung: Move to modern EHR system
# - Erwarteter Nutzen: Streamlined data access
#
# 2. Quality Control Automation
# - Unternehmen: Pioneer Industrial Products (Manufacturing)
# - Beschreibung: Computer vision defect detection
# - Erwarteter Nutzen: Improved quality
#
# Insgesamt gibt es 2 Use Cases mit dem Status "abgeschlossen".
#
# --- TEST 4: Natural Language Status ---
#
# User: Mark use case 2 as done
#
#
# The agent wants to call 1 tools.
#
# Agent calls update_use_case_status
# Arguments: {'use_case_id': 2, 'status': 'completed'}
# Success: updated titleupdated titleupdated titleupdated titleupdated titleupdated titleupdated titleupdated titleupdated titleAI Diagnostics
#
# Sending results back to LLM for final answer...
# Agent: The use case 2 has been successfully marked as completed. The system has confirmed the update, and the use case's status is now "completed".
#
# --- TEST 5: Status Variation ---
#
# User: Set use case 3 to 'reviewing'
#
#
# The agent wants to call 1 tools.
#
# Agent calls update_use_case_status
# Arguments: {'use_case_id': 3, 'status': 'in_review'}
# Success: EHR Migration
#
# Sending results back to LLM for final answer...
# Agent: The use case has been successfully updated. Use case #3 "EHR Migration" is now in review status.
#
# --- TEST 6: Filter Combination ---
#
# User: Show me all use cases in industry 1 that are approved
#
#
# The agent wants to call 1 tools.
#
# Agent calls filter_use_cases
# Arguments: {'industry_id': 1, 'status': 'approved'}
# Returned 0 items
#
# Sending results back to LLM for final answer...
# Agent: Based on the results, there are no approved use cases in industry 1. Would you like to:
# 1. See all use cases in industry 1 regardless of status?
# 2. See approved use cases across all industries?
# 3. Get more information about a different industry?
#
# Please let me know how you'd like to proceed.
#
# --- TEST 7: Create with German ---
#
# User: Erstelle einen neuen Use Case 'Test Deutsch' für Firma 1 in Branche 1 mit Status 'genehmigt'
#
#
# The agent wants to call 1 tools.
#
# Agent calls create_use_case
# Arguments: {'title': 'Test Deutsch', 'company_id': 1, 'industry_id': 1, 'status': 'approved'}
# Success: Test Deutsch
#
# Sending results back to LLM for final answer...
# Agent: Der Use Case wurde erfolgreich erstellt:
# - Titel: Test Deutsch
# - Firma: MediCare Solutions Inc. (ID: 1)
# - Branche: Healthcare (ID: 1)
# - Status: genehmigt
# - Use Case ID: 23
#
# Die Erstellung war erfolgreich. Möchten Sie weitere Informationen zu diesem Use Case hinzufügen oder eine andere Aktion ausführen?
# 'Der Use Case wurde erfolgreich erstellt:\n- Titel: Test Deutsch\n- Firma: MediCare Solutions Inc. (ID: 1)\n- Branche: Healthcare (ID: 1)\n- Status: genehmigt\n- Use Case ID: 23\n\nDie Erstellung war erfolgreich. Möchten Sie weitere Informationen zu diesem Use Case hinzufügen oder eine andere Aktion ausführen?'

# %%
print("\n--- TEST 8:  ---")
run_agent("Please show me all IT related use cases", verbose=True)
# Out:
# --- TEST 8:  ---
#
# User: Please show me all IT related use cases
#
#
# The agent wants to call 1 tools.
#
# Agent calls filter_use_cases
# Arguments: {'industry_id': 1}
# Returned 4 items
#
# Sending results back to LLM for final answer...
# Agent: Here are all the IT-related use cases from the database:
#
# 1. Patient Portal
#    - Description: Portal online for patients
#    - Expected Benefit: Better patient administration
#    - Status: In Review
#    - Company: MediCare Solutions Inc.
#
# 2. AI Diagnostics
#    - Description: ML for medical imaging
#    - Expected Benefit: Faster diagnosis
#    - Status: Completed
#    - Company: HealthFirst Medical Group
#
# 3. EHR Migration
#    - Description: Move to modern EHR system
#    - Expected Benefit: Streamlined data access
#    - Status: In Review
#    - Company: CarePlus Health Services
#
# 4. Test Deutsch
#    - Status: Approved
#    - Company: MediCare Solutions Inc.
#    (Note: This appears to be a test entry as it lacks description and expected benefits)
#
# All these use cases are associated with healthcare IT implementations. They represent various technological solutions aimed at improving healthcare delivery and administration.
#
# Would you like more specific information about any of these use cases?
# 'Here are all the IT-related use cases from the database:\n\n1. Patient Portal\n   - Description: Portal online for patients\n   - Expected Benefit: Better patient administration\n   - Status: In Review\n   - Company: MediCare Solutions Inc.\n\n2. AI Diagnostics\n   - Description: ML for medical imaging\n   - Expected Benefit: Faster diagnosis\n   - Status: Completed\n   - Company: HealthFirst Medical Group\n\n3. EHR Migration\n   - Description: Move to modern EHR system\n   - Expected Benefit: Streamlined data access\n   - Status: In Review\n   - Company: CarePlus Health Services\n\n4. Test Deutsch\n   - Status: Approved\n   - Company: MediCare Solutions Inc.\n   (Note: This appears to be a test entry as it lacks description and expected benefits)\n\nAll these use cases are associated with healthcare IT implementations. They represent various technological solutions aimed at improving healthcare delivery and administration.\n\nWould you like more specific information about any of these use cases?'
