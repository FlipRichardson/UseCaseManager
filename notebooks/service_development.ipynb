# %%
import sys
import os

# Add parent directory
parent_dir = os.path.dirname(os.getcwd())
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

os.chdir(parent_dir)

from models.base import SessionLocal
from models import UseCase, Company, Industry, Person
from typing import Optional, List, Dict, Any

# %% [markdown]
# # Use Case Service Class
# Should implement all interaction functionality with db

# %%
class UseCaseService:
    """
    Layer that is intented to handle all interaction with the database for managin usecases. 
    CRUD operation.
    """
    def __init__(self):
        self.valid_status_values = [
            "new",
            "in_review",
            "approved",
            "in_progress",
            "completed",
            "archived"
        ]

    def _get_session(self):
        """Helper to get database session"""
        return SessionLocal()  # may get more complicated dont know, if so can be handeled centrally here
    
    def _validate_status(self, status : str) -> None:
        if status not in self.valid_status_values:
            valid_status_valus = ", ".join(self.valid_status_values)
            raise ValueError(f"Given status '{status}' is not valid. Please choose one of the following status values '{valid_status_valus}'")
    
    def _use_case_to_dict(self, use_case : UseCase) -> Dict[str, Any]: 
        """
        Helper function translating a use case to a dict. 
        Args: 
            use_case : Use case abj

        Returns: 
            Dict containing use case information EXCEPT persons involved
        """
        return {
            "id": use_case.id,
            "title": use_case.title,
            "description": use_case.description,
            "expected_benefit": use_case.expected_benefit,
            "status": use_case.status,
            "company_id": use_case.company_id,
            "company_name": use_case.company.name,
            "industry_id": use_case.industry_id,
            "industry_name": use_case.industry.name
        }


    
    def get_all_use_cases(self) -> List[Dict[str, Any]]: 
        # get db
        db = self._get_session()

        # try to get all use cases and format them reasonably
        try: 
            use_cases = db.query(UseCase).all()
            print(use_cases)
            return [self._use_case_to_dict(uc) for uc in use_cases]
        finally:
            db.close()

    def get_use_case_by_id(self, use_case_id : int) -> Optional[Dict[str, Any]]:
        """
        get the use case for the identifier provided.
        """
        
        db = self._get_session()

        try: 
            matching_use_case = db.query(UseCase).filter(UseCase.id == use_case_id).first()

            if not matching_use_case:
                return None
            else:
                return self._use_case_to_dict(matching_use_case)
        finally:
            db.close()

    def create_use_case(self, title : str, company_id : int, industry_id : int, description : str = None, expected_benefit : str = None, status : str  = 'new') -> Dict[str, Any]:

        db = self._get_session()

        try:

            # checks
            # (1) is company existing?
            company = db.query(Company).filter(Company.id == company_id).first()
            if not company:
                raise ValueError(f"Company with ID {company_id} does not exist.")
            
            # (2) is industry existing?
            industry = db.query(Industry).filter(Industry.id == industry_id).first()
            if not industry:
                raise ValueError(f"Industry with ID {industry_id} does not exist.")
            
            # (3) title may not be empty
            if len(title) == 0: # TODO also check fro upper limit
                raise ValueError("Title must not be empty.")

            # (4) status in valid range
            self._validate_status(status)

            # if ok lets create a new use case
            new_use_case = UseCase(
                title = title,
                description = description, 
                expected_benefit = expected_benefit, 
                company_id = company_id, 
                industry_id = industry_id, 
                status = status
            )
            
            # add and save
            db.add(new_use_case)
            db.commit()
            db.refresh(new_use_case)

            return self._use_case_to_dict(new_use_case)
        
        except Exception as e:  # hope thats alright TODO check if rollback is correct or if there is no error handling needed
            db.rollback()
            raise e
        
        finally:
            db.close()

    def update_use_case(
            self, 
            use_case_id : int, 
            title : Optional[str] = None, 
            description : Optional[str] = None, 
            expected_benefit : Optional[str] = None, 
            status : Optional[str] = None, 
            company_id : Optional[int] = None, 
            industry_id : Optional[int] = None
            ) -> Dict[str, Any]:
        """ 
        Update an use case specified by use_case id. Only arguments provided will be updated. 

        Args:
            ...
        
        Returns: 
            updated use case as dictionary.
        """
        
        db = self._get_session()

        try: 
            # check if valid id
            use_case_in_question = db.query(UseCase).filter(UseCase.id == use_case_id).first()
            if not use_case_in_question:
                raise ValueError(f"Given Id {use_case_id} not found in database.")
            
            # updated parameter if provided
            # (1) Title
            if title is not None:
                if len(title) == 0:  # TODO also check for upper limit!
                    raise ValueError(f"Title must not be empty.")
                use_case_in_question.title = title
            
            # (2) Description
            if description is not None: 
                use_case_in_question.description = description
            
            # (3) Expected benefit
            if expected_benefit is not None:
                use_case_in_question.expected_benefit = expected_benefit
            
            # (4) Status
            if status is not None:
                self._validate_status(status)
                use_case_in_question.status = status

            # (5) Company id
            if company_id is not None: 
                # check if company exists
                company = db.query(Company).filter(Company.id == company_id).first()
                if not company:
                    ValueError(f"Company with ID {company_id} does not exist. ")
                use_case_in_question.company_id = company_id
            
            # (6) Industry
            if industry_id is not None:
                # check if industry exists
                industry = db.query(Industry).filter(Industry.id == industry_id).first()
                if not industry:
                    raise ValueError(f"Industry with ID {industry_id} does not exist. ")
            
            # save
            db.commit()
            db.refresh(use_case_in_question)

            return self._use_case_to_dict(use_case_in_question)
        
        except Exception as e: 
             db.rollback()
             raise e 
        
        finally:
            db.close()


    def update_use_case_status(self, use_case_id : int, status : str) -> Dict[str, Any]: 
        """ 
        Update the status of an use case specifed by the ID. 

        Args: 
            status. str
        Reurns:
            Dictionay of updated use case. 
        """
        return self.update_use_case(use_case_id = use_case_id, status = status)
    
    def delete_use_case(self, use_case_id : int) -> Dict[str, Any]:
        """ 
        Delete one use case from the database and returns its informatin  for the last time.

        Args:
            use_case_id (int) : I dod the use case to be deleted

        Returns:
            dict of informatin of te use case that has been deleted.
        """

        db = self._get_session()

        try: 
            # check if is is valid
            use_case_to_be_deleted = db.query(UseCase).filter(UseCase.id == use_case_id).first()
            if not use_case_to_be_deleted:
                raise ValueError(f"Use case with ID {use_case_id} not found in database.")
            
            use_case_dict = self._use_case_to_dict(use_case_to_be_deleted)  # for final returning it
            
            # do the deletion
            db.delete(use_case_to_be_deleted)
            db.commit()

            return use_case_dict

        except Exception as e:
            db.rollback()
            raise e

        finally:
            db.close()

    def filter_use_cases(
            self, 
            company_id : Optional[int] = None, 
            industry_id : Optional[int] = None, 
            status : Optional[str] = None, 
            person_id : Optional[int] = None
    ) -> List[Dict[str, Any]]: 
        """ 
        Filter use cases by various criteria.
        All filters are optional.
        
        Args:
            industry_id: Filter by industry ID (optional)
            company_id: Filter by company ID (optional)
            status: Filter by status (optional)
            person_id: Filter by person who contributed (optional)
            
        Returns:
            List of use cases matching the filters
        """

        db = self._get_session()

        try:

            query = db.query(UseCase)

            # uif company is provided
            if company_id is not None: 
                query = query.filter(UseCase.company_id == company_id)
            
            # filter industry
            if industry_id is not None: 
                query = query.filter(UseCase.industry_id == industry_id)

            # filer status
            if status is not None:  # no checks needed here
                query = query.filter(UseCase.status == status)

            # filter person
            if person_id is not None: 
                query = query.join(UseCase.persons).filter(Person.id == person_id)

            # run filter
            filtered_use_cases = query.all()

            return [self._use_case_to_dict(uc) for uc in filtered_use_cases]

        finally:
            db.close()

    def archive_use_case(self, use_case_id : int) -> Dict[str, Any]: 
        """
        Sets the status of a use case to archived. 

        Args: 
            use_case_id (int) : use case id of use case to be archived

        Returns:
            Dict of the use case that has been archived
        """ 
        return self.update_use_case_status(use_case_id, "archived")

            
    def __repr__(self):
        return "<UseCaseService>"

# %%
service = UseCaseService()

# %% [markdown]
# # test get all use cases

# %%
print(service.get_all_use_cases())
# Out:
# 2026-02-13 17:22:18,185 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,187 INFO sqlalchemy.engine.Engine SELECT use_cases.id AS use_cases_id, use_cases.title AS use_cases_title, use_cases.description AS use_cases_description, use_cases.expected_benefit AS use_cases_expected_benefit, use_cases.status AS use_cases_status, use_cases.company_id AS use_cases_company_id, use_cases.industry_id AS use_cases_industry_id
# FROM use_cases
# 2026-02-13 17:22:18,188 INFO sqlalchemy.engine.Engine [generated in 0.00052s] ()
# [<UseCase(id=1, title='Patient protal', status='archived', company_id=1)>, <UseCase(id=2, title='updated titleupdated titleupdated titleupdated titleupdated titleupdated titleupdated titleupdated titleAI Diagnostics', status='in_progress', company_id=2)>, <UseCase(id=3, title='EHR Migration', status='completed', company_id=3)>, <UseCase(id=4, title='Cloud Migration', status='new', company_id=4)>, <UseCase(id=5, title='Mobile App Dev', status='in_progress', company_id=5)>, <UseCase(id=6, title='Cybersecurity Program', status='new', company_id=6)>, <UseCase(id=7, title='IoT Sensors', status='in_progress', company_id=7)>, <UseCase(id=8, title='Supply Chain Optimization', status='new', company_id=8)>, <UseCase(id=9, title='Quality Control Automation', status='completed', company_id=9)>, <UseCase(id=10, title='Test Use Case - Automated Testing', status='new', company_id=6)>, <UseCase(id=11, title='Test Use Case - Automated Testing', status='new', company_id=6)>, <UseCase(id=12, title='Test Use Case - Automated Testing', status='new', company_id=6)>, <UseCase(id=13, title='Test Use Case - Automated Testing', status='new', company_id=6)>, <UseCase(id=14, title='Test Use Case - Automated Testing', status='new', company_id=6)>, <UseCase(id=15, title='Test Use Case - Automated Testing', status='new', company_id=6)>, <UseCase(id=16, title='Test Use Case - Automated Testing', status='new', company_id=6)>, <UseCase(id=17, title='Test Use Case - Automated Testing', status='new', company_id=6)>, <UseCase(id=18, title='Test Use Case - Automated Testing', status='new', company_id=6)>]
# 2026-02-13 17:22:18,190 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,190 INFO sqlalchemy.engine.Engine [generated in 0.00038s] (1,)
# 2026-02-13 17:22:18,191 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
# 2026-02-13 17:22:18,192 INFO sqlalchemy.engine.Engine [generated in 0.00038s] (1,)
# 2026-02-13 17:22:18,193 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,193 INFO sqlalchemy.engine.Engine [cached since 0.003342s ago] (2,)
# 2026-02-13 17:22:18,194 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,194 INFO sqlalchemy.engine.Engine [cached since 0.004353s ago] (3,)
# 2026-02-13 17:22:18,195 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,195 INFO sqlalchemy.engine.Engine [cached since 0.005329s ago] (4,)
# 2026-02-13 17:22:18,196 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
# 2026-02-13 17:22:18,196 INFO sqlalchemy.engine.Engine [cached since 0.005097s ago] (2,)
# 2026-02-13 17:22:18,197 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,198 INFO sqlalchemy.engine.Engine [cached since 0.008104s ago] (5,)
# 2026-02-13 17:22:18,199 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,199 INFO sqlalchemy.engine.Engine [cached since 0.009172s ago] (6,)
# 2026-02-13 17:22:18,200 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,200 INFO sqlalchemy.engine.Engine [cached since 0.01038s ago] (7,)
# 2026-02-13 17:22:18,201 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
# 2026-02-13 17:22:18,201 INFO sqlalchemy.engine.Engine [cached since 0.009943s ago] (3,)
# 2026-02-13 17:22:18,202 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,202 INFO sqlalchemy.engine.Engine [cached since 0.0125s ago] (8,)
# 2026-02-13 17:22:18,203 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,203 INFO sqlalchemy.engine.Engine [cached since 0.01353s ago] (9,)
# 2026-02-13 17:22:18,204 INFO sqlalchemy.engine.Engine ROLLBACK
# [{'id': 1, 'title': 'Patient protal', 'description': 'Protal online for patients', 'expected_benefit': 'Better patient administration', 'status': 'archived', 'company_id': 1, 'company_name': 'MediCare Solutions Inc.', 'industry_id': 1, 'industry_name': 'Healthcare'}, {'id': 2, 'title': 'updated titleupdated titleupdated titleupdated titleupdated titleupdated titleupdated titleupdated titleAI Diagnostics', 'description': 'updated descriptionupdated descriptionupdated descriptionupdated descriptionupdated descriptionupdated descriptionupdated descriptionupdated descriptionML for medical imaging', 'expected_benefit': 'Faster diagnosis', 'status': 'in_progress', 'company_id': 2, 'company_name': 'HealthFirst Medical Group', 'industry_id': 1, 'industry_name': 'Healthcare'}, {'id': 3, 'title': 'EHR Migration', 'description': 'Move to modern EHR system', 'expected_benefit': 'Streamlined data access', 'status': 'completed', 'company_id': 3, 'company_name': 'CarePlus Health Services', 'industry_id': 1, 'industry_name': 'Healthcare'}, {'id': 4, 'title': 'Cloud Migration', 'description': 'Move to AWS cloud', 'expected_benefit': 'Reduced costs', 'status': 'new', 'company_id': 4, 'company_name': 'DataStream Systems', 'industry_id': 2, 'industry_name': 'IT'}, {'id': 5, 'title': 'Mobile App Dev', 'description': 'iOS and Android apps', 'expected_benefit': 'Increased engagement', 'status': 'in_progress', 'company_id': 5, 'company_name': 'TechVision Innovations', 'industry_id': 2, 'industry_name': 'IT'}, {'id': 6, 'title': 'Cybersecurity Program', 'description': 'Enhanced security measures', 'expected_benefit': 'Reduced risks', 'status': 'new', 'company_id': 6, 'company_name': 'ByteForge Solutions', 'industry_id': 2, 'industry_name': 'IT'}, {'id': 7, 'title': 'IoT Sensors', 'description': 'Real-time equipment monitoring', 'expected_benefit': 'Reduced downtime', 'status': 'in_progress', 'company_id': 7, 'company_name': 'Precision Parts Industries', 'industry_id': 3, 'industry_name': 'Manufacturing'}, {'id': 8, 'title': 'Supply Chain Optimization', 'description': 'Automated inventory system', 'expected_benefit': 'Lower inventory costs', 'status': 'new', 'company_id': 8, 'company_name': 'Global Fabrication Systems', 'industry_id': 3, 'industry_name': 'Manufacturing'}, {'id': 9, 'title': 'Quality Control Automation', 'description': 'Computer vision defect detection', 'expected_benefit': 'Improved quality', 'status': 'completed', 'company_id': 9, 'company_name': 'Pioneer Industrial Products', 'industry_id': 3, 'industry_name': 'Manufacturing'}, {'id': 10, 'title': 'Test Use Case - Automated Testing', 'description': 'Implement automated testing framework for quality assurance', 'expected_benefit': 'Reduce bugs by 50%, faster deployment cycles', 'status': 'new', 'company_id': 6, 'company_name': 'ByteForge Solutions', 'industry_id': 2, 'industry_name': 'IT'}, {'id': 11, 'title': 'Test Use Case - Automated Testing', 'description': 'Implement automated testing framework for quality assurance', 'expected_benefit': 'Reduce bugs by 50%, faster deployment cycles', 'status': 'new', 'company_id': 6, 'company_name': 'ByteForge Solutions', 'industry_id': 2, 'industry_name': 'IT'}, {'id': 12, 'title': 'Test Use Case - Automated Testing', 'description': 'Implement automated testing framework for quality assurance', 'expected_benefit': 'Reduce bugs by 50%, faster deployment cycles', 'status': 'new', 'company_id': 6, 'company_name': 'ByteForge Solutions', 'industry_id': 2, 'industry_name': 'IT'}, {'id': 13, 'title': 'Test Use Case - Automated Testing', 'description': 'Implement automated testing framework for quality assurance', 'expected_benefit': 'Reduce bugs by 50%, faster deployment cycles', 'status': 'new', 'company_id': 6, 'company_name': 'ByteForge Solutions', 'industry_id': 2, 'industry_name': 'IT'}, {'id': 14, 'title': 'Test Use Case - Automated Testing', 'description': 'Implement automated testing framework for quality assurance', 'expected_benefit': 'Reduc ...

# %% [markdown]
# # test get use case by id

# %%
use_case_2 = service.get_use_case_by_id(999)
# Out:
# 2026-02-13 17:22:18,210 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,212 INFO sqlalchemy.engine.Engine SELECT use_cases.id AS use_cases_id, use_cases.title AS use_cases_title, use_cases.description AS use_cases_description, use_cases.expected_benefit AS use_cases_expected_benefit, use_cases.status AS use_cases_status, use_cases.company_id AS use_cases_company_id, use_cases.industry_id AS use_cases_industry_id
# FROM use_cases
# WHERE use_cases.id = ?
#  LIMIT ? OFFSET ?
# 2026-02-13 17:22:18,212 INFO sqlalchemy.engine.Engine [generated in 0.00047s] (999, 1, 0)
# 2026-02-13 17:22:18,213 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# # create new usecase

# %%
new_uc = service.create_use_case(
    title="Test Use Case - Automated Testing",
    description="Implement automated testing framework for quality assurance",
    expected_benefit="Reduce bugs by 50%, faster deployment cycles",
    company_id=6,
    industry_id=2,
    status="new"
)
# Out:
# 2026-02-13 17:22:18,219 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,220 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
#  LIMIT ? OFFSET ?
# 2026-02-13 17:22:18,221 INFO sqlalchemy.engine.Engine [generated in 0.00042s] (6, 1, 0)
# 2026-02-13 17:22:18,222 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
#  LIMIT ? OFFSET ?
# 2026-02-13 17:22:18,222 INFO sqlalchemy.engine.Engine [generated in 0.00061s] (2, 1, 0)
# 2026-02-13 17:22:18,224 INFO sqlalchemy.engine.Engine INSERT INTO use_cases (title, description, expected_benefit, status, company_id, industry_id) VALUES (?, ?, ?, ?, ?, ?)
# 2026-02-13 17:22:18,224 INFO sqlalchemy.engine.Engine [generated in 0.00050s] ('Test Use Case - Automated Testing', 'Implement automated testing framework for quality assurance', 'Reduce bugs by 50%, faster deployment cycles', 'new', 6, 2)
# 2026-02-13 17:22:18,225 INFO sqlalchemy.engine.Engine COMMIT
# 2026-02-13 17:22:18,228 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,229 INFO sqlalchemy.engine.Engine SELECT use_cases.id, use_cases.title, use_cases.description, use_cases.expected_benefit, use_cases.status, use_cases.company_id, use_cases.industry_id
# FROM use_cases
# WHERE use_cases.id = ?
# 2026-02-13 17:22:18,230 INFO sqlalchemy.engine.Engine [generated in 0.00073s] (19,)
# 2026-02-13 17:22:18,231 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,231 INFO sqlalchemy.engine.Engine [generated in 0.00043s] (6,)
# 2026-02-13 17:22:18,233 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
# 2026-02-13 17:22:18,233 INFO sqlalchemy.engine.Engine [generated in 0.00036s] (2,)
# 2026-02-13 17:22:18,233 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
retrieved = service.get_use_case_by_id(new_uc['id'])

# test cases that should not work
if 1 == 2:
    service.create_use_case(
            title="Should Fail",
            description="This should fail",
            expected_benefit="None",
            company_id=20000,  # Invalid ID
            industry_id=1,
            status="new" # invalid status
        )

    service.create_use_case(
            title="Should Fail",
            description="This should fail",
            expected_benefit="None",
            company_id=2,  # Invalid ID
            industry_id=1,
            status="newd" # invalid status
        )
# Out:
# 2026-02-13 17:22:18,240 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,241 INFO sqlalchemy.engine.Engine SELECT use_cases.id AS use_cases_id, use_cases.title AS use_cases_title, use_cases.description AS use_cases_description, use_cases.expected_benefit AS use_cases_expected_benefit, use_cases.status AS use_cases_status, use_cases.company_id AS use_cases_company_id, use_cases.industry_id AS use_cases_industry_id
# FROM use_cases
# WHERE use_cases.id = ?
#  LIMIT ? OFFSET ?
# 2026-02-13 17:22:18,241 INFO sqlalchemy.engine.Engine [cached since 0.02997s ago] (19, 1, 0)
# 2026-02-13 17:22:18,242 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,243 INFO sqlalchemy.engine.Engine [cached since 0.05337s ago] (6,)
# 2026-02-13 17:22:18,244 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
# 2026-02-13 17:22:18,244 INFO sqlalchemy.engine.Engine [cached since 0.05316s ago] (2,)
# 2026-02-13 17:22:18,245 INFO sqlalchemy.engine.Engine ROLLBACK

# %% [markdown]
# # test update use case

# %%
# get some use case
uc = service.get_use_case_by_id(2)

# update something
updated_uc = service.update_use_case(2, title="updated title"+uc['title'], description="updated description"+uc['description'])

print(f"Updated Use case, title {updated_uc['title']} and description {updated_uc['description']}")
# Out:
# 2026-02-13 17:22:18,255 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,256 INFO sqlalchemy.engine.Engine SELECT use_cases.id AS use_cases_id, use_cases.title AS use_cases_title, use_cases.description AS use_cases_description, use_cases.expected_benefit AS use_cases_expected_benefit, use_cases.status AS use_cases_status, use_cases.company_id AS use_cases_company_id, use_cases.industry_id AS use_cases_industry_id
# FROM use_cases
# WHERE use_cases.id = ?
#  LIMIT ? OFFSET ?
# 2026-02-13 17:22:18,256 INFO sqlalchemy.engine.Engine [cached since 0.04476s ago] (2, 1, 0)
# 2026-02-13 17:22:18,258 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,258 INFO sqlalchemy.engine.Engine [cached since 0.06854s ago] (2,)
# 2026-02-13 17:22:18,259 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
# 2026-02-13 17:22:18,260 INFO sqlalchemy.engine.Engine [cached since 0.06906s ago] (1,)
# 2026-02-13 17:22:18,261 INFO sqlalchemy.engine.Engine ROLLBACK
# 2026-02-13 17:22:18,262 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,263 INFO sqlalchemy.engine.Engine SELECT use_cases.id AS use_cases_id, use_cases.title AS use_cases_title, use_cases.description AS use_cases_description, use_cases.expected_benefit AS use_cases_expected_benefit, use_cases.status AS use_cases_status, use_cases.company_id AS use_cases_company_id, use_cases.industry_id AS use_cases_industry_id
# FROM use_cases
# WHERE use_cases.id = ?
#  LIMIT ? OFFSET ?
# 2026-02-13 17:22:18,263 INFO sqlalchemy.engine.Engine [cached since 0.05196s ago] (2, 1, 0)
# 2026-02-13 17:22:18,266 INFO sqlalchemy.engine.Engine UPDATE use_cases SET title=?, description=? WHERE use_cases.id = ?
# 2026-02-13 17:22:18,267 INFO sqlalchemy.engine.Engine [generated in 0.00111s] ('updated titleupdated titleupdated titleupdated titleupdated titleupdated titleupdated titleupdated titleupdated titleAI Diagnostics', 'updated descriptionupdated descriptionupdated descriptionupdated descriptionupdated descriptionupdated descriptionupdated descriptionupdated descriptionupdated descriptionML for medical imaging', 2)
# 2026-02-13 17:22:18,269 INFO sqlalchemy.engine.Engine COMMIT
# 2026-02-13 17:22:18,272 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,273 INFO sqlalchemy.engine.Engine SELECT use_cases.id, use_cases.title, use_cases.description, use_cases.expected_benefit, use_cases.status, use_cases.company_id, use_cases.industry_id
# FROM use_cases
# WHERE use_cases.id = ?
# 2026-02-13 17:22:18,273 INFO sqlalchemy.engine.Engine [cached since 0.04429s ago] (2,)
# 2026-02-13 17:22:18,275 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,276 INFO sqlalchemy.engine.Engine [cached since 0.08598s ago] (2,)
# 2026-02-13 17:22:18,277 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
# 2026-02-13 17:22:18,278 INFO sqlalchemy.engine.Engine [cached since 0.08642s ago] (1,)
# 2026-02-13 17:22:18,279 INFO sqlalchemy.engine.Engine ROLLBACK
# Updated Use case, title updated titleupdated titleupdated titleupdated titleupdated titleupdated titleupdated titleupdated titleupdated titleAI Diagnostics and description updated descriptionupdated descriptionupdated descriptionupdated descriptionupdated descriptionupdated descriptionupdated descriptionupdated descriptionupdated descriptionML for medical imaging

# %%
status_updated = service.update_use_case_status(1, "in_progress")
print(f"Status changed to: {status_updated['status']}")
# Out:
# 2026-02-13 17:22:18,288 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,289 INFO sqlalchemy.engine.Engine SELECT use_cases.id AS use_cases_id, use_cases.title AS use_cases_title, use_cases.description AS use_cases_description, use_cases.expected_benefit AS use_cases_expected_benefit, use_cases.status AS use_cases_status, use_cases.company_id AS use_cases_company_id, use_cases.industry_id AS use_cases_industry_id
# FROM use_cases
# WHERE use_cases.id = ?
#  LIMIT ? OFFSET ?
# 2026-02-13 17:22:18,289 INFO sqlalchemy.engine.Engine [cached since 0.0778s ago] (1, 1, 0)
# 2026-02-13 17:22:18,291 INFO sqlalchemy.engine.Engine UPDATE use_cases SET status=? WHERE use_cases.id = ?
# 2026-02-13 17:22:18,292 INFO sqlalchemy.engine.Engine [generated in 0.00101s] ('in_progress', 1)
# 2026-02-13 17:22:18,294 INFO sqlalchemy.engine.Engine COMMIT
# 2026-02-13 17:22:18,298 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,299 INFO sqlalchemy.engine.Engine SELECT use_cases.id, use_cases.title, use_cases.description, use_cases.expected_benefit, use_cases.status, use_cases.company_id, use_cases.industry_id
# FROM use_cases
# WHERE use_cases.id = ?
# 2026-02-13 17:22:18,300 INFO sqlalchemy.engine.Engine [cached since 0.07077s ago] (1,)
# 2026-02-13 17:22:18,302 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,302 INFO sqlalchemy.engine.Engine [cached since 0.1126s ago] (1,)
# 2026-02-13 17:22:18,304 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
# 2026-02-13 17:22:18,304 INFO sqlalchemy.engine.Engine [cached since 0.1131s ago] (1,)
# 2026-02-13 17:22:18,306 INFO sqlalchemy.engine.Engine ROLLBACK
# Status changed to: in_progress

# %%
if 1 == 2:
    service.update_use_case_status(1, "invalid_status")
    service.update_use_case(9999, title="Should fail")

# %% [markdown]
# # testing Filter

# %%
new_cases = service.filter_use_cases(status="new")
print(f"Found {len(new_cases)} use cases with status 'new'")
for uc in new_cases[:3]:  
    print(f"{uc['title']}")


industry_cases = service.filter_use_cases(industry_id=1)
print(f"Found {len(industry_cases)} use cases in industry")
for uc in industry_cases[:3]:
    print(f"{uc['title']} ({uc['industry_name']})")
# Out:
# 2026-02-13 17:22:18,324 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,326 INFO sqlalchemy.engine.Engine SELECT use_cases.id AS use_cases_id, use_cases.title AS use_cases_title, use_cases.description AS use_cases_description, use_cases.expected_benefit AS use_cases_expected_benefit, use_cases.status AS use_cases_status, use_cases.company_id AS use_cases_company_id, use_cases.industry_id AS use_cases_industry_id
# FROM use_cases
# WHERE use_cases.status = ?
# 2026-02-13 17:22:18,327 INFO sqlalchemy.engine.Engine [generated in 0.00078s] ('new',)
# 2026-02-13 17:22:18,328 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,329 INFO sqlalchemy.engine.Engine [cached since 0.1393s ago] (4,)
# 2026-02-13 17:22:18,330 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
# 2026-02-13 17:22:18,331 INFO sqlalchemy.engine.Engine [cached since 0.1399s ago] (2,)
# 2026-02-13 17:22:18,332 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,333 INFO sqlalchemy.engine.Engine [cached since 0.1433s ago] (6,)
# 2026-02-13 17:22:18,334 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,335 INFO sqlalchemy.engine.Engine [cached since 0.1453s ago] (8,)
# 2026-02-13 17:22:18,336 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
# 2026-02-13 17:22:18,337 INFO sqlalchemy.engine.Engine [cached since 0.146s ago] (3,)
# 2026-02-13 17:22:18,338 INFO sqlalchemy.engine.Engine ROLLBACK
# Found 13 use cases with status 'new'
# Cloud Migration
# Cybersecurity Program
# Supply Chain Optimization
# 2026-02-13 17:22:18,340 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,341 INFO sqlalchemy.engine.Engine SELECT use_cases.id AS use_cases_id, use_cases.title AS use_cases_title, use_cases.description AS use_cases_description, use_cases.expected_benefit AS use_cases_expected_benefit, use_cases.status AS use_cases_status, use_cases.company_id AS use_cases_company_id, use_cases.industry_id AS use_cases_industry_id
# FROM use_cases
# WHERE use_cases.industry_id = ?
# 2026-02-13 17:22:18,342 INFO sqlalchemy.engine.Engine [generated in 0.00077s] (1,)
# 2026-02-13 17:22:18,344 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,344 INFO sqlalchemy.engine.Engine [cached since 0.1548s ago] (1,)
# 2026-02-13 17:22:18,346 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
# 2026-02-13 17:22:18,346 INFO sqlalchemy.engine.Engine [cached since 0.1551s ago] (1,)
# 2026-02-13 17:22:18,348 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,349 INFO sqlalchemy.engine.Engine [cached since 0.159s ago] (2,)
# 2026-02-13 17:22:18,350 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,351 INFO sqlalchemy.engine.Engine [cached since 0.1611s ago] (3,)
# 2026-02-13 17:22:18,352 INFO sqlalchemy.engine.Engine ROLLBACK
# Found 3 use cases in industry
# Patient protal (Healthcare)
# updated titleupdated titleupdated titleupdated titleupdated titleupdated titleupdated titleupdated titleupdated titleAI Diagnostics (Healthcare)
# EHR Migration (Healthcare)

# %%
combined = service.filter_use_cases(industry_id=1, status="in_progress")
print(f"Found {len(combined)} use cases")
for uc in combined:
    print(f"{uc['title']}")
# Out:
# 2026-02-13 17:22:18,362 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,363 INFO sqlalchemy.engine.Engine SELECT use_cases.id AS use_cases_id, use_cases.title AS use_cases_title, use_cases.description AS use_cases_description, use_cases.expected_benefit AS use_cases_expected_benefit, use_cases.status AS use_cases_status, use_cases.company_id AS use_cases_company_id, use_cases.industry_id AS use_cases_industry_id
# FROM use_cases
# WHERE use_cases.industry_id = ? AND use_cases.status = ?
# 2026-02-13 17:22:18,364 INFO sqlalchemy.engine.Engine [generated in 0.00088s] (1, 'in_progress')
# 2026-02-13 17:22:18,366 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,367 INFO sqlalchemy.engine.Engine [cached since 0.1772s ago] (1,)
# 2026-02-13 17:22:18,368 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
# 2026-02-13 17:22:18,369 INFO sqlalchemy.engine.Engine [cached since 0.178s ago] (1,)
# 2026-02-13 17:22:18,371 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,372 INFO sqlalchemy.engine.Engine [cached since 0.1818s ago] (2,)
# 2026-02-13 17:22:18,373 INFO sqlalchemy.engine.Engine ROLLBACK
# Found 2 use cases
# Patient protal
# updated titleupdated titleupdated titleupdated titleupdated titleupdated titleupdated titleupdated titleupdated titleAI Diagnostics

# %%
all_cases = service.filter_use_cases()
print(f"Found {len(all_cases)} total use cases")
# Out:
# 2026-02-13 17:22:18,382 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,383 INFO sqlalchemy.engine.Engine SELECT use_cases.id AS use_cases_id, use_cases.title AS use_cases_title, use_cases.description AS use_cases_description, use_cases.expected_benefit AS use_cases_expected_benefit, use_cases.status AS use_cases_status, use_cases.company_id AS use_cases_company_id, use_cases.industry_id AS use_cases_industry_id
# FROM use_cases
# 2026-02-13 17:22:18,383 INFO sqlalchemy.engine.Engine [cached since 0.1961s ago] ()
# 2026-02-13 17:22:18,385 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,385 INFO sqlalchemy.engine.Engine [cached since 0.1956s ago] (1,)
# 2026-02-13 17:22:18,386 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
# 2026-02-13 17:22:18,387 INFO sqlalchemy.engine.Engine [cached since 0.1957s ago] (1,)
# 2026-02-13 17:22:18,388 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,388 INFO sqlalchemy.engine.Engine [cached since 0.1987s ago] (2,)
# 2026-02-13 17:22:18,390 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,390 INFO sqlalchemy.engine.Engine [cached since 0.2001s ago] (3,)
# 2026-02-13 17:22:18,391 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,391 INFO sqlalchemy.engine.Engine [cached since 0.2014s ago] (4,)
# 2026-02-13 17:22:18,392 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
# 2026-02-13 17:22:18,392 INFO sqlalchemy.engine.Engine [cached since 0.201s ago] (2,)
# 2026-02-13 17:22:18,393 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,394 INFO sqlalchemy.engine.Engine [cached since 0.2038s ago] (5,)
# 2026-02-13 17:22:18,394 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,395 INFO sqlalchemy.engine.Engine [cached since 0.205s ago] (6,)
# 2026-02-13 17:22:18,396 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,397 INFO sqlalchemy.engine.Engine [cached since 0.207s ago] (7,)
# 2026-02-13 17:22:18,398 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
# 2026-02-13 17:22:18,398 INFO sqlalchemy.engine.Engine [cached since 0.207s ago] (3,)
# 2026-02-13 17:22:18,399 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,399 INFO sqlalchemy.engine.Engine [cached since 0.2097s ago] (8,)
# 2026-02-13 17:22:18,401 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,402 INFO sqlalchemy.engine.Engine [cached since 0.2121s ago] (9,)
# 2026-02-13 17:22:18,403 INFO sqlalchemy.engine.Engine ROLLBACK
# Found 19 total use cases

# %% [markdown]
# # testing delete use case

# %%
print("\nCreating a test use case to delete...")
test_uc = service.create_use_case(
    title="TEST - Will be deleted",
    company_id=1,
    industry_id=1,
    status="new"
)
print(f"Created use case #{test_uc['id']}: {test_uc['title']}")

# Delete it
print(f"\nDeleting use case #{test_uc['id']}...")
deleted = service.delete_use_case(test_uc['id'])
print(f"Deleted: {deleted['title']}")

# Verify it's gone
print("\nVerifying deletion...")
result = service.get_use_case_by_id(test_uc['id'])
if result is None:
    print("Use case successfully deleted (returns None)")
else:
    print("Use case still exists!")

# Test delete with non-existent ID
print("\nTesting delete with non-existent ID...")
try:
    service.delete_use_case(9999)
    print("Should have raised ValueError")
except ValueError as e:
    print(f"Correctly raised error: {e}")
# Out:
# Creating a test use case to delete...
# 2026-02-13 17:22:18,414 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,415 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
#  LIMIT ? OFFSET ?
# 2026-02-13 17:22:18,416 INFO sqlalchemy.engine.Engine [cached since 0.1957s ago] (1, 1, 0)
# 2026-02-13 17:22:18,417 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
#  LIMIT ? OFFSET ?
# 2026-02-13 17:22:18,418 INFO sqlalchemy.engine.Engine [cached since 0.196s ago] (1, 1, 0)
# 2026-02-13 17:22:18,419 INFO sqlalchemy.engine.Engine INSERT INTO use_cases (title, description, expected_benefit, status, company_id, industry_id) VALUES (?, ?, ?, ?, ?, ?)
# 2026-02-13 17:22:18,420 INFO sqlalchemy.engine.Engine [cached since 0.1962s ago] ('TEST - Will be deleted', None, None, 'new', 1, 1)
# 2026-02-13 17:22:18,422 INFO sqlalchemy.engine.Engine COMMIT
# 2026-02-13 17:22:18,426 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,427 INFO sqlalchemy.engine.Engine SELECT use_cases.id, use_cases.title, use_cases.description, use_cases.expected_benefit, use_cases.status, use_cases.company_id, use_cases.industry_id
# FROM use_cases
# WHERE use_cases.id = ?
# 2026-02-13 17:22:18,427 INFO sqlalchemy.engine.Engine [cached since 0.1983s ago] (20,)
# 2026-02-13 17:22:18,429 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,430 INFO sqlalchemy.engine.Engine [cached since 0.1985s ago] (1,)
# 2026-02-13 17:22:18,431 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
# 2026-02-13 17:22:18,432 INFO sqlalchemy.engine.Engine [cached since 0.1991s ago] (1,)
# 2026-02-13 17:22:18,433 INFO sqlalchemy.engine.Engine ROLLBACK
# Created use case #20: TEST - Will be deleted
#
# Deleting use case #20...
# 2026-02-13 17:22:18,434 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,434 INFO sqlalchemy.engine.Engine SELECT use_cases.id AS use_cases_id, use_cases.title AS use_cases_title, use_cases.description AS use_cases_description, use_cases.expected_benefit AS use_cases_expected_benefit, use_cases.status AS use_cases_status, use_cases.company_id AS use_cases_company_id, use_cases.industry_id AS use_cases_industry_id
# FROM use_cases
# WHERE use_cases.id = ?
#  LIMIT ? OFFSET ?
# 2026-02-13 17:22:18,435 INFO sqlalchemy.engine.Engine [cached since 0.2233s ago] (20, 1, 0)
# 2026-02-13 17:22:18,436 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,436 INFO sqlalchemy.engine.Engine [cached since 0.2467s ago] (1,)
# 2026-02-13 17:22:18,437 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
# 2026-02-13 17:22:18,438 INFO sqlalchemy.engine.Engine [cached since 0.2465s ago] (1,)
# 2026-02-13 17:22:18,440 INFO sqlalchemy.engine.Engine SELECT persons.id AS persons_id, persons.name AS persons_name, persons.role AS persons_role, persons.company_id AS persons_company_id
# FROM persons, use_case_person
# WHERE ? = use_case_person.use_case_id AND persons.id = use_case_person.person_id
# 2026-02-13 17:22:18,440 INFO sqlalchemy.engine.Engine [generated in 0.00050s] (20,)
# 2026-02-13 17:22:18,441 INFO sqlalchemy.engine.Engine DELETE FROM use_cases WHERE use_cases.id = ?
# 2026-02-13 17:22:18,442 INFO sqlalchemy.engine.Engine [generated in 0.00044s] (20,)
# 2026-02-13 17:22:18,443 INFO sqlalchemy.engine.Engine COMMIT
# Deleted: TEST - Will be deleted
#
# Verifying deletion...
# 2026-02-13 17:22:18,446 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,447 INFO sqlalchemy.engine.Engine SELECT use_cases.id AS use_cases_id, use_cases.title AS use_cases_title, use_cases.description AS use_cases_description, use_cases.expected_benefit AS use_cases_expected_benefit, use_cases.status AS use_cases_status, use_cases.company_id AS use_cases_company_id, use_cases.industry_id AS use_cases_industry_id
# FROM use_cases
# WHERE use_cases.id = ?
#  LIMIT ? OFFSET ?
# 2026-02-13 17:22:18,447 INFO sqlalchemy.engine.Engine [cached since 0.2357s ago] (20, 1, 0)
# 2026-02-13 17:22:18,448 INFO sqlalchemy.engine.Engine ROLLBACK
# Use case successfully deleted (returns None)
#
# Testing delete with non-existent ID...
# 2026-02-13 17:22:18,449 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,449 INFO sqlalchemy.engine.Engine SELECT use_cases.id AS use_cases_id, use_cases.title AS use_cases_title, use_cases.description AS use_cases_description, use_cases.expected_benefit AS use_cases_expected_benefit, use_cases.status AS use_cases_status, use_cases.company_id AS use_cases_company_id, use_cases.industry_id AS use_cases_industry_id
# FROM use_cases
# WHERE use_cases.id = ?
#  LIMIT ? OFFSET ?
# 2026-02-13 17:22:18,449 INFO sqlalchemy.engine.Engine [cached since 0.2377s ago] (9999, 1, 0)
# 2026-02-13 17:22:18,450 INFO sqlalchemy.engine.Engine ROLLBACK
# Correctly raised error: Use case with ID 9999 not found in database.

# %% [markdown]
# # test Archive functionality

# %%
service = UseCaseService()

# Get a use case to archive
uc = service.get_use_case_by_id(1)
print(f"Before archiving:")
print(f"Use case #{uc['id']}: {uc['title']}")
print(f"Status: {uc['status']}")

# Archive it
print(f"\nArchiving use case #{uc['id']}...")
archived = service.archive_use_case(1)
print(f"Archived!")
print(f"New status: {archived['status']}")

# Verify with filter
print("\nChecking archived use cases...")
archived_cases = service.filter_use_cases(status="archived")
print(f"Found {len(archived_cases)} archived use case(s)")
for ac in archived_cases:
    print(f"{ac['title']}")
# Out:
# 2026-02-13 17:22:18,456 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,457 INFO sqlalchemy.engine.Engine SELECT use_cases.id AS use_cases_id, use_cases.title AS use_cases_title, use_cases.description AS use_cases_description, use_cases.expected_benefit AS use_cases_expected_benefit, use_cases.status AS use_cases_status, use_cases.company_id AS use_cases_company_id, use_cases.industry_id AS use_cases_industry_id
# FROM use_cases
# WHERE use_cases.id = ?
#  LIMIT ? OFFSET ?
# 2026-02-13 17:22:18,457 INFO sqlalchemy.engine.Engine [cached since 0.2458s ago] (1, 1, 0)
# 2026-02-13 17:22:18,458 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,459 INFO sqlalchemy.engine.Engine [cached since 0.2688s ago] (1,)
# 2026-02-13 17:22:18,460 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
# 2026-02-13 17:22:18,460 INFO sqlalchemy.engine.Engine [cached since 0.2688s ago] (1,)
# 2026-02-13 17:22:18,461 INFO sqlalchemy.engine.Engine ROLLBACK
# Before archiving:
#   Use case #1: Patient protal
#   Status: in_progress
#
# Archiving use case #1...
# 2026-02-13 17:22:18,462 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,462 INFO sqlalchemy.engine.Engine SELECT use_cases.id AS use_cases_id, use_cases.title AS use_cases_title, use_cases.description AS use_cases_description, use_cases.expected_benefit AS use_cases_expected_benefit, use_cases.status AS use_cases_status, use_cases.company_id AS use_cases_company_id, use_cases.industry_id AS use_cases_industry_id
# FROM use_cases
# WHERE use_cases.id = ?
#  LIMIT ? OFFSET ?
# 2026-02-13 17:22:18,462 INFO sqlalchemy.engine.Engine [cached since 0.251s ago] (1, 1, 0)
# 2026-02-13 17:22:18,463 INFO sqlalchemy.engine.Engine UPDATE use_cases SET status=? WHERE use_cases.id = ?
# 2026-02-13 17:22:18,464 INFO sqlalchemy.engine.Engine [cached since 0.1725s ago] ('archived', 1)
# 2026-02-13 17:22:18,465 INFO sqlalchemy.engine.Engine COMMIT
# 2026-02-13 17:22:18,468 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,468 INFO sqlalchemy.engine.Engine SELECT use_cases.id, use_cases.title, use_cases.description, use_cases.expected_benefit, use_cases.status, use_cases.company_id, use_cases.industry_id
# FROM use_cases
# WHERE use_cases.id = ?
# 2026-02-13 17:22:18,469 INFO sqlalchemy.engine.Engine [cached since 0.2394s ago] (1,)
# 2026-02-13 17:22:18,470 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,470 INFO sqlalchemy.engine.Engine [cached since 0.2803s ago] (1,)
# 2026-02-13 17:22:18,471 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
# 2026-02-13 17:22:18,471 INFO sqlalchemy.engine.Engine [cached since 0.2801s ago] (1,)
# 2026-02-13 17:22:18,472 INFO sqlalchemy.engine.Engine ROLLBACK
# ✓ Archived!
#   New status: archived
#
# Checking archived use cases...
# 2026-02-13 17:22:18,473 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 17:22:18,473 INFO sqlalchemy.engine.Engine SELECT use_cases.id AS use_cases_id, use_cases.title AS use_cases_title, use_cases.description AS use_cases_description, use_cases.expected_benefit AS use_cases_expected_benefit, use_cases.status AS use_cases_status, use_cases.company_id AS use_cases_company_id, use_cases.industry_id AS use_cases_industry_id
# FROM use_cases
# WHERE use_cases.status = ?
# 2026-02-13 17:22:18,474 INFO sqlalchemy.engine.Engine [cached since 0.1477s ago] ('archived',)
# 2026-02-13 17:22:18,474 INFO sqlalchemy.engine.Engine SELECT companies.id AS companies_id, companies.name AS companies_name, companies.industry_id AS companies_industry_id
# FROM companies
# WHERE companies.id = ?
# 2026-02-13 17:22:18,475 INFO sqlalchemy.engine.Engine [cached since 0.2851s ago] (1,)
# 2026-02-13 17:22:18,476 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# WHERE industries.id = ?
# 2026-02-13 17:22:18,476 INFO sqlalchemy.engine.Engine [cached since 0.2847s ago] (1,)
# 2026-02-13 17:22:18,476 INFO sqlalchemy.engine.Engine ROLLBACK
# ✓ Found 1 archived use case(s)
#   - Patient protal
