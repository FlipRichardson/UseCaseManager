# %%
from models.base import Base, engine, SessionLocal
from models import Industry

# %%
# create dummy database
db = SessionLocal()
Base.metadata.create_all(bind=engine)
# Out:
# 2026-02-13 09:39:29,051 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 09:39:29,052 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("industries")
# 2026-02-13 09:39:29,053 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-02-13 09:39:29,054 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("industries")
# 2026-02-13 09:39:29,054 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-02-13 09:39:29,055 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("companies")
# 2026-02-13 09:39:29,055 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-02-13 09:39:29,056 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("companies")
# 2026-02-13 09:39:29,057 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-02-13 09:39:29,058 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("persons")
# 2026-02-13 09:39:29,059 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-02-13 09:39:29,060 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("persons")
# 2026-02-13 09:39:29,061 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-02-13 09:39:29,062 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("use_case_person")
# 2026-02-13 09:39:29,063 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-02-13 09:39:29,064 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("use_case_person")
# 2026-02-13 09:39:29,065 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-02-13 09:39:29,065 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("use_cases")
# 2026-02-13 09:39:29,066 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-02-13 09:39:29,066 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("use_cases")
# 2026-02-13 09:39:29,067 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-02-13 09:39:29,067 INFO sqlalchemy.engine.Engine
# CREATE TABLE industries (
# 	id INTEGER NOT NULL,
# 	name VARCHAR(100) NOT NULL,
# 	PRIMARY KEY (id),
# 	UNIQUE (name)
# )
#
#
# 2026-02-13 09:39:29,068 INFO sqlalchemy.engine.Engine [no key 0.00036s] ()
# 2026-02-13 09:39:29,072 INFO sqlalchemy.engine.Engine
# CREATE TABLE companies (
# 	id INTEGER NOT NULL,
# 	name VARCHAR(200) NOT NULL,
# 	industry_id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(industry_id) REFERENCES industries (id)
# )
#
#
# 2026-02-13 09:39:29,073 INFO sqlalchemy.engine.Engine [no key 0.00061s] ()
# 2026-02-13 09:39:29,077 INFO sqlalchemy.engine.Engine
# CREATE TABLE persons (
# 	id INTEGER NOT NULL,
# 	name VARCHAR(200) NOT NULL,
# 	role VARCHAR(200),
# 	company_id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(company_id) REFERENCES companies (id)
# )
#
#
# 2026-02-13 09:39:29,077 INFO sqlalchemy.engine.Engine [no key 0.00070s] ()
# 2026-02-13 09:39:29,081 INFO sqlalchemy.engine.Engine
# CREATE TABLE use_cases (
# 	id INTEGER NOT NULL,
# 	title VARCHAR(300) NOT NULL,
# 	description TEXT,
# 	expected_benefit TEXT,
# 	status VARCHAR(50) NOT NULL,
# 	company_id INTEGER NOT NULL,
# 	industry_id INTEGER NOT NULL,
# 	created_at DATETIME DEFAULT (CURRENT_TIMESTAMP),
# 	updated_at DATETIME DEFAULT (CURRENT_TIMESTAMP),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(company_id) REFERENCES companies (id),
# 	FOREIGN KEY(industry_id) REFERENCES industries (id)
# )
#
#
# 2026-02-13 09:39:29,082 INFO sqlalchemy.engine.Engine [no key 0.00065s] ()
# 2026-02-13 09:39:29,085 INFO sqlalchemy.engine.Engine
# CREATE TABLE use_case_person (
# 	use_case_id INTEGER NOT NULL,
# 	person_id INTEGER NOT NULL,
# 	PRIMARY KEY (use_case_id, person_id),
# 	FOREIGN KEY(use_case_id) REFERENCES use_cases (id),
# 	FOREIGN KEY(person_id) REFERENCES persons (id)
# )
#
#
# 2026-02-13 09:39:29,086 INFO sqlalchemy.engine.Engine [no key 0.00078s] ()
# 2026-02-13 09:39:29,089 INFO sqlalchemy.engine.Engine COMMIT

# %%
# test creation of industry instance
industry_healthcare = Industry(name = 'Healthcare')
industry_it = Industry(name = 'IT')
industry_manufacturing = Industry(name = 'Manufacturing')

# %%
# add them to the database
db.add(industry_healthcare)
db.add(industry_it)
db.add(industry_manufacturing)

# %%
# save db
db.commit()
# Out:
# 2026-02-13 09:39:31,523 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-13 09:39:31,525 INFO sqlalchemy.engine.Engine INSERT INTO industries (name) VALUES (?) RETURNING id
# 2026-02-13 09:39:31,525 INFO sqlalchemy.engine.Engine [generated in 0.00007s (insertmanyvalues) 1/3 (ordered; batch not supported)] ('Healthcare',)
# 2026-02-13 09:39:31,527 INFO sqlalchemy.engine.Engine INSERT INTO industries (name) VALUES (?) RETURNING id
# 2026-02-13 09:39:31,527 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/3 (ordered; batch not supported)] ('IT',)
# 2026-02-13 09:39:31,528 INFO sqlalchemy.engine.Engine INSERT INTO industries (name) VALUES (?) RETURNING id
# 2026-02-13 09:39:31,528 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/3 (ordered; batch not supported)] ('Manufacturing',)
# 2026-02-13 09:39:31,529 INFO sqlalchemy.engine.Engine COMMIT

# %%
# retreive data
industries = db.query(Industry)
for industry in industries:
    print(industry, industry.name, industry.id)
# Out:
# 2026-02-13 09:43:34,204 INFO sqlalchemy.engine.Engine SELECT industries.id AS industries_id, industries.name AS industries_name
# FROM industries
# 2026-02-13 09:43:34,204 INFO sqlalchemy.engine.Engine [cached since 24.91s ago] ()
# <Industry(id=1, name='Healthcare')> Healthcare 1
# <Industry(id=2, name='IT')> IT 2
# <Industry(id=3, name='Manufacturing')> Manufacturing 3
